# %%
import imageio

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = imageio.imread('toad_and_jiang.jpg')

# %%
plt.imshow(img)

# %%
import cv2

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img[:,:,0], cmap='gray')

# %%
plt.imshow(img[:,:,1], cmap='gray')

# %%
plt.imshow(img[:,:,2], cmap='gray')

# %%
plt.imshow(img_gray[:,:140], cmap='gray')

# %%
plt.hist(img_gray.flatten(), bins='auto')
# Out:
# (array([ 667., 1409., 3253., 2428., 3520., 3128., 1745., 2009., 1808.,
#         1369., 1579., 1313., 1172., 1514., 1421., 1417., 1341.,  963.,
#         1033.,  729.,  925.,  900.,  592., 1047., 5874., 2097.,  777.,
#          388.,  501.,  555.,  532.,  387.,  390.,  214.,  210.,  190.,
#          117.,  136.,  244.,  338.]),
#  array([  0.   ,   6.375,  12.75 ,  19.125,  25.5  ,  31.875,  38.25 ,
#          44.625,  51.   ,  57.375,  63.75 ,  70.125,  76.5  ,  82.875,
#          89.25 ,  95.625, 102.   , 108.375, 114.75 , 121.125, 127.5  ,
#         133.875, 140.25 , 146.625, 153.   , 159.375, 165.75 , 172.125,
#         178.5  , 184.875, 191.25 , 197.625, 204.   , 210.375, 216.75 ,
#         223.125, 229.5  , 235.875, 242.25 , 248.625, 255.   ]),
#  <a list of 40 Patch objects>)

# %%
plt.imshow(img_gray[:,:140] >140, cmap='gray')

# %%
plt.imshow(img_gray[:,:140] >160, cmap='gray')

# %%
plt.imshow(img_gray[:,:140] >50, cmap='gray')

# %%
imageio.imwrite('images/toad_rgb.png', img[:,:140,:])
imageio.imwrite('images/toad_r.png', img[:,:140,0])
imageio.imwrite('images/toad_g.png', img[:,:140,1])
imageio.imwrite('images/toad_b.png', img[:,:140,2])

# %%
m,n = img[:,:140,2].shape

# %%
img[m//2-3:m//2+3,n//2-3:n//2+3,2]
# Out:
# Image([[ 5,  7, 10, 10, 11,  4],
#        [ 6,  8,  8, 10, 10,  5],
#        [ 5,  6,  8,  8,  7,  4],
#        [ 6,  5,  6,  5,  7,  5],
#        [ 6,  6,  4,  5,  4,  4],
#        [ 5,  5,  4,  2,  3,  6]], dtype=uint8)

# %%
plt.imshow(img[m//2-3:m//2+3,n//2-3:n//2+3,2], cmap='gray')

# %%
plt.imshow(img[m//2-30:m//2+30,n//2-30:n//2+30,2], cmap='gray')

# %%
arr =  img[m//2-3:m//2+3,n//2-3:n//2+3,2]

# %%
for line in arr:
    print(' & '.join([str(n) for n in line]) + r' \\')
# Out:
# 5 & 7 & 10 & 10 & 11 & 4 \\
# 6 & 8 & 8 & 10 & 10 & 5 \\
# 5 & 6 & 8 & 8 & 7 & 4 \\
# 6 & 5 & 6 & 5 & 7 & 5 \\
# 6 & 6 & 4 & 5 & 4 & 4 \\
# 5 & 5 & 4 & 2 & 3 & 6 \\

# %%
line
# Out:
# Image([5, 5, 4, 2, 3, 6], dtype=uint8)

# %%
m,n
# Out:
# (168, 140)
